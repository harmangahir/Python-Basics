# %% [markdown]
# **Question: 1** In the below elements which of them are values or an expression? eg:- values can be integer or string and expressions will be mathematical operators.
# *
# 'hello'
# -87.8
# -
# /
# +
# 6

# %% [markdown]
# **Answer:**
#
#
# * \* is an expression
# * 'hello' is a value
# * 87.8 is a value
# * \- is an expression
# * \/ is an expression
# * \+	is an expression
# * 6 is a value

# %% [markdown]
# **Question: 2** What is the difference between string and variable?

# %% [markdown]
# **Answer:**
#
# String is a series of alphanumeric/special characters or even space enclosed in pair of single/double/tripple quote.
#
# Variable is a area where we can store a value. It could be integer, character, float or a string.

# %% [markdown]
# **Question 3:** Describe three different data types.

# %% [markdown]
# **Answer:**
#
# 1. Numeric:
#         Integer means 0-9,
#         Float means 1.2
#         Complex 3 + 4j
# 2. Text
#     String means 'abc01 @', "abc01 @", '''abc01 @'''
#
# 3. Sequence
#         List means [1.2, 9.08,'Harman']
#         tuple means (1.2, 9.08,'Harman')
# 4. Boolean
#     bool means 0|1, Yes|No, True|False

# %% [markdown]
# **Question 4:** What is an expression made up of? What do all expressions do?

# %% [markdown]
# **Answer:**
#
#     Expression is made up operators and operands. Such as 4 + 3(6*5) where 4,3,6 and 5 are operands and +,* are operators
#     Expression gives the result after perform calculation inside it.

# %% [markdown]
# **Question 5:** This assignment statements, like spam = 10. What is the difference between an expression and a statement?

# %% [markdown]
# **Answer:**
#
# Expression return value after perform calculation inside it where as statement may or may not return any value.

# %% [markdown]
# **Question 6:** After running the following code, what does the variable bacon contain?
# bacon = 22
# bacon + 1

# %% [markdown]
# **Answer:**
#
# bacon = 22 is an assigment of integer value 22 to variable bacon whereas,
# bacon + 1 will add 1 into bacon's current value.

# %% [markdown]
# **Question 7:** What should the values of the following two terms be?
# 'spam' + 'spamspam'
# 'spam' * 3
#
# **Answer:**
#
# 'spam' + 'spamspam' will gives output as spamspamspam
# 'spam' * 3 will gives spamspamspam

# %% [markdown]
# **Question 8:** Why is eggs a valid variable name while 100 is invalid?
#
# **Answer:**
#
# Variable name can be starts with albhabet or with underscore(_) but not with digit

# %% [markdown]
# **Question 9:** What three functions can be used to get the integer, floating-point number, or string version of a value?
#
# **Answer:**
#
#     int() for integer number
#     float() for float number
#     str() for string

# %% [markdown]
# **Question 10:** Why does this expression cause an error? How can you fix it?'I have eaten ' + 99 + ' burritos.'
#
# **Answer:**
#
#     Expression cause an error because 99 is an integer.
#     Correct way is: 'I have eaten ' + str(99) + ' burritos.'
